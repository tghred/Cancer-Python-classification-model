# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
book1= pd.read_csv('C://Users//HP//last one//new//new.csv')
book1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      ID first_name      mid_name    last_name  \
# 0           0             0  136497      MANAL  ABDUL MONAEM       HUSEEN
# 1           1             1   60633       AFAF         AHMED         TAHA
# 2           2             2  163602     KARIMA  ABDEL HAFEAZ  ABDEL HAMED
# 3           3             3  277205     NAGLAA       MOHAMED  ABDEL KADIR
# 4           4             4  104692     SAADIA       IBRAHIM          ALI
#
#          phone sex status        city  ... risk of cardiac desease  \
# 0  01128837215   F      S       Asyut  ...                       1
# 1  01112843051   F      M       Sohag  ...                       0
# 2            0   F      M        Qena  ...                       1
# 3     33032755   F      M  Alexandria  ...                       1
# 4     35821534   F      M        Idfu  ...                       0
#
#   previos surgery  current symptoms  Risk for thromboembolism Sleep_apnea  \
# ...

# %%
fol2=fol2.dropna()

# %%
fol2.head()
# Out:
#   MRI 2  LD 2 (cm)  no. of nodes Node-Coded Tumor staging Node Metastasis  \
# 0   yes       5.63           6.0   Positive            T3   N3         M0
# 2   yes      14.63           1.0   Positive            T4   N1         M0
# 3   yes      17.50           0.0   Negative            T4   N0         M0
# 4   yes       2.38          10.0   Positive            T2   N3         M0
# 5   yes       7.75           0.0   Negative            T3   N0         M0
#
#    AJCC Stage diagnose date(2)      ID
# 0  Stage IIIC       2009-07-09  136497
# 2  Stage IIIA       2009-09-30  163602
# 3   Stage IIB       2009-04-06  277205
# 4  Stage IIIC       2009-07-30  104692
# 5   Stage IIB       2009-12-28  450825

# %% [markdown]
# # Check Stage logic

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='stage',y='LD1',data=book1)

# %%
plt.figure(figsize=(13,8))
sns.boxplot(x='stage',y='LD1',data=book1,hue='surgery',palette='Spectral')

# %%
plt.figure(figsize=(13,8))
sns.boxplot(x='stage',y='LD1',data=book1,hue='hermonal',palette='plasma')

# %%
plt.figure(figsize=(13,8))
sns.boxplot(x='stage',y='LD1',data=book1,hue='chemo',palette='Blues')

# %% [markdown]
# # Check Nodes

# %%
plt.figure(figsize=(13,8))

sns.violinplot(x='node ',y='LD1',data=book1)

# %%
plt.figure(figsize=(13,8))

sns.stripplot(x='NO of node',y='LD1',data=book1,palette='Spectral')

# %%
plt.figure(figsize=(13,8))
sns.countplot(x='node ',data=book1,hue='surgery',palette='plasma')

# %%
plt.figure(figsize=(13,8))

sns.countplot(x='node ',data=book1,hue='chemo',palette='viridis')

# %%
plt.figure(figsize=(13,8))

sns.countplot(x='node ',data=book1,hue='hermonal',palette='Blues')

# %%
plt.figure(figsize=(13,8))

sns.countplot(x='node ',data=book1,hue='censor',palette='Reds')

# %% [markdown]
# # Check tumor

# %%
plt.figure(figsize=(13,8))

sns.stripplot(x='tumor stage',y='LD1',data=book1,palette='YlGnBu')

# %%
plt.figure(figsize=(13,8))
sns.countplot(x='tumor stage',data=book1,hue='surgery',palette='plasma')

# %%
plt.figure(figsize=(13,8))
sns.countplot(x='tumor stage',data=book1,hue='chemo',palette='winter')

# %%
plt.figure(figsize=(13,8))
sns.countplot(x='tumor stage',data=book1,hue='hermonal',palette='summer')

# %%
plt.figure(figsize=(13,8))
sns.countplot(x='tumor stage',data=book1,hue='censor',palette='spring')

# %% [markdown]
# # Ln col

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='ln',data=book1)

# %%
plt.figure(figsize=(15,8))
sns.stripplot(x='ln',y='LD1',data=book1)

# %% [markdown]
# # Tests

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='stage',y='LD1',data=book1,hue='ER+',palette='Spectral')

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='stage',y='LD1',data=book1,hue='PR+',palette='Spectral')

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='PR+',data=book1,palette='Spectral')

# %%
plt.figure(figsize=(15,8))
sns.distplot(book1['LD1'],bins=30)

# %%
#'diagnose_date','date_ofbirth'
import datetime
x=book1['diagnose_date']
dti = pd.to_datetime(x)
